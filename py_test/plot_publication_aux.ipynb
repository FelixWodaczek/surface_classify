# %% [markdown]
# # Plotting Figures that are less Calculation Intensive
#
# This script is for Fig. 2 and 3, which rely on data calculated through auxiliary calculations.
# The data is added here in the form of lists.

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
from energydiagram import ED
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patches
from matplotlib.lines import Line2D
import numpy as np

# %% [markdown]
# ## Figure 2

# %%
plt.rcParams.update(plt.rcParamsDefault)
fontsize = 12
if True:
    font = {'family': 'serif', 'size': fontsize}
    plt.rc('font', **font)
    plt.rc('text', usetex=True)
    plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

fig = plt.figure(figsize=(11, 6))

lmarg=0.05

axes = []
axes.append(fig.add_axes((0, 0.5+lmarg, 0.3, 0.5-lmarg))) # First logplot top
axes.append(fig.add_axes((0.35, 0.5+lmarg, 0.3, 0.5-lmarg))) # First logplot top
axes.append(fig.add_axes((0.7, 0.5+lmarg, 0.3, 0.5-lmarg))) # First logplot top

pd_color = "tab:orange"
rh_color = "tab:blue"

#111

diagram = ED()
diagram.bottom_text_fontsize = fontsize
diagram.add_level(0,r'$\mathrm{IS}$',top_text='')

diagram.add_level(0.19,r'$\mathrm{FS1}$', color=pd_color,top_text='') #Rh111p_text='') #Rh111
diagram.add_level(0.26,'','last', color=rh_color,top_text='') #Pd11111


diagram.add_level(0.73,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.20,'','last', color=rh_color,top_text='')


diagram.add_level(0.58,r'$\mathrm{FS2}$', color=pd_color,top_text='')
diagram.add_level(0.97,'','last', color=rh_color,top_text='')


diagram.add_level(0.76,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.56,'','last', color=rh_color,top_text='')


diagram.add_level(0.36,r'$\mathrm{FS3}$', color=pd_color,top_text='')
diagram.add_level(0.97,'','last', color=rh_color,top_text='')


diagram.add_level(0.38,r'$\mathrm{FS4}$', color=pd_color,top_text='')
diagram.add_level(0.71,'','last', color=rh_color,top_text='')


diagram.add_level(0.65,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.25,'','last', color=rh_color,top_text='')

diagram.add_level(0.59,r'$\mathrm{FS5}$', color=pd_color,top_text='')
diagram.add_level(1.06,'','last', color=rh_color,top_text='')

diagram.add_level(0.89,r'$\mathrm{FS6}$',top_text='')

diagram.add_link(0,1)
diagram.add_link(0,2)
diagram.add_link(1,3)
diagram.add_link(2,4)
diagram.add_link(3,5)
diagram.add_link(4,6)
diagram.add_link(5,7)
diagram.add_link(6,8)
diagram.add_link(7,9)
diagram.add_link(8,10)
diagram.add_link(9,11)
diagram.add_link(10,12)
diagram.add_link(11,13)
diagram.add_link(12,14)
diagram.add_link(13,15)
diagram.add_link(14,16)

diagram.add_link(15,17)
diagram.add_link(16,17)

plt.rcParams.update({'font.size': 12})

diagram.plot(ylabel="Free Energy (eV)", ax=axes[0])

#100

diagram = ED()
diagram.bottom_text_fontsize = fontsize
diagram.add_level(0,r'$\mathrm{IS}$',top_text='')

diagram.add_level(0.19,r'$\mathrm{FS1}$', color=pd_color,top_text='') #Rh111_text='') #Rh111
diagram.add_level(0.21,'','last', color=rh_color,top_text='') #Pd1111


diagram.add_level(0.75,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.20,'','last', color=rh_color,top_text='')


diagram.add_level(0.25,r'$\mathrm{FS2}$', color=pd_color,top_text='')
diagram.add_level(0.79,'','last', color=rh_color,top_text='')


diagram.add_level(0.29,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.25,'','last', color=rh_color,top_text='')


diagram.add_level(-0.24,r'$\mathrm{FS3}$', color=pd_color,top_text='')
diagram.add_level(0.50,'','last', color=rh_color,top_text='')


diagram.add_level(0.27,r'$\mathrm{FS4}$', color=pd_color,top_text='')
diagram.add_level(0.63,'','last', color=rh_color,top_text='')


diagram.add_level(0.52,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.22,'','last', color=rh_color,top_text='')

diagram.add_level(0.47,r'$\mathrm{FS5}$', color=pd_color,top_text='')
diagram.add_level(0.97,'','last', color=rh_color,top_text='')

diagram.add_level(0.89,r'$\mathrm{FS6}$',top_text='')

diagram.add_link(0,1)
diagram.add_link(0,2)
diagram.add_link(1,3)
diagram.add_link(2,4)
diagram.add_link(3,5)
diagram.add_link(4,6)
diagram.add_link(5,7)
diagram.add_link(6,8)
diagram.add_link(7,9)
diagram.add_link(8,10)
diagram.add_link(9,11)
diagram.add_link(10,12)
diagram.add_link(11,13)
diagram.add_link(12,14)
diagram.add_link(13,15)
diagram.add_link(14,16)

diagram.add_link(15,17)
diagram.add_link(16,17)

plt.rcParams.update({'font.size': 12})

diagram.plot(ylabel='', ax=axes[1])

# plt.savefig('100pathway.pdf')

#110

diagram = ED()
diagram.bottom_text_fontsize = fontsize
diagram.add_level(0,r'$\mathrm{IS}$',top_text='')

diagram.add_level(0.25,r'$\mathrm{FS1}$', color=pd_color,top_text='') #Rh111
diagram.add_level(0.27,'','last', color=rh_color,top_text='') #Pd111


diagram.add_level(0.72,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.29,'','last', color=rh_color,top_text='')


diagram.add_level(0.22,r'$\mathrm{FS2}$', color=pd_color,top_text='')
diagram.add_level(0.85,'','last', color=rh_color,top_text='')


diagram.add_level(0.58,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.64,'','last', color=rh_color,top_text='')


diagram.add_level(0.09,r'$\mathrm{FS3}$', color=pd_color,top_text='')
diagram.add_level(0.82,'','last', color=rh_color,top_text='')


diagram.add_level(0.23,r'$\mathrm{FS4}$', color=pd_color,top_text='')
diagram.add_level(0.82,'','last', color=rh_color,top_text='')


diagram.add_level(0.54,r'$\ddag$', color=pd_color,top_text='')
diagram.add_level(1.19,'','last', color=rh_color,top_text='')

diagram.add_level(0.49,r'$\mathrm{FS5}$', color=pd_color,top_text='')
diagram.add_level(0.95,'','last', color=rh_color,top_text='')

diagram.add_level(0.89,r'$\mathrm{FS6}$',top_text='')

diagram.add_link(0,1)
diagram.add_link(0,2)
diagram.add_link(1,3)
diagram.add_link(2,4)
diagram.add_link(3,5)
diagram.add_link(4,6)
diagram.add_link(5,7)
diagram.add_link(6,8)
diagram.add_link(7,9)
diagram.add_link(8,10)
diagram.add_link(9,11)
diagram.add_link(10,12)
diagram.add_link(11,13)
diagram.add_link(12,14)
diagram.add_link(13,15)
diagram.add_link(14,16)

diagram.add_link(15,17)
diagram.add_link(16,17)

diagram.plot(ylabel='', ax=axes[2])

max_y = [0, 0]
for axis in axes:
    max_y[0] = min(max_y[0], axis.get_ylim()[0])
    max_y[1] = max(max_y[1], axis.get_ylim()[1])
for axis in axes:
    axis.set_ylim([-.5, 2])
    axis.set_aspect(0.7)

#axes[1].set_axis_off()
#axes[2].set_axis_off()

axes[1].legend(handles=[
    patches.Patch(facecolor='tab:blue', label='Palladium'),
    patches.Patch(facecolor='tab:orange', label='Rhodium')
], fontsize=fontsize)

# Now for bottom plot
bar_ax = fig.add_axes((0, 0.2, 0.5, 0.3))

Palladium = np.array([1.970249e-02, 4.653179e-03, 6.216751e-03, 9.130835e-09, 1.421196e-07, 3.180858e-02,
            3.873732e-06, 2.207631e-04, 7.291755e-07, 1.873654e-06, 1.275488e-06, 2.568031e-06, 1.791322e-09])
Rhodium = np.array([2.947998e-01, 4.076129e+00, 2.213683e+00, 1.360925e-02, 4.343079e-03, 1.279555e+01,
           1.363255e+00, 1.273051e-01, 1.756916e-03, 3.369158e-01, 3.047968e-02, 1.655088e-03, 9.261856e-04])

assert np.all(Palladium<Rhodium), "Palladium more active than Rhodium at some site"

plot_rh = Rhodium-Palladium

labels = ['(111) adatom', '(100) adatom', '(111) adatom pair', '(110) adatom', '(111) terrace', '(211) adatom',
'(100) terrace', '(100)-(110) interface', '(110)', '(211)', '(100)', '(111) vacancy', '(111)']
# Get old labels for label_color_dict
if False:
    reg_labels = [list(prettylabel_dict.keys())[list(prettylabel_dict.values()).index(label)] for label in labels]
    draw_colors = []
    for reg_label in reg_labels:
            try:
                draw_colors.append(label_color_dict[reg_label])
            except:
                draw_colors.append('gray')


width = 0.8 # the width of the bars: can also be len(x) sequence

# plt.rcParams["hatch.linewidth"] = 2
bar_ax.bar(np.arange(len(labels)), Palladium, width, label='Palladium', color='tab:blue') # , hatch=r"//", edgecolor="w")
bar_ax.bar(np.arange(len(labels)), plot_rh, width, bottom=Palladium, label='Rhodium', color='tab:orange')

bar_ax.set_yscale("log")
bar_ax.set_ylim([1e-10, 1e4])
bar_ax.set_ylabel(r'Rate (s$^{-1}$)', fontsize=fontsize)
bar_ax.legend(fontsize=fontsize)

bar_ax.set_xticks(np.arange(len(labels)), labels=labels, rotation=-35, rotation_mode="anchor", ha='left', fontsize=fontsize)


plt.show()
fig.savefig('fig2_ratepathways.pdf', bbox_inches='tight', dpi=300)

# %% [markdown]
# ## Figure 3

# %%
experimental_rh_data = np.array([
    # [442.9979692079911, -7.836389525243357e-10],
    [448.0113244165225, 2.187186336004382e-7],
    [452.99486799851945, 5.88071014362268e-7],
    [458.0116245335681, 0.0000010757111940323392],
    [462.9656566060764, 0.000001618572910101607],
    [468.0464381108632, 0.0000021535148707996124],
    [473.00127049549326, 0.0000027594678591317297],
    [477.96050459679276, 0.0000037124228449095157],
    [483.01407548944087, 0.000004602261548670649],
    [487.977311151349, 0.000005870672895762683],
    # [623, 2.1e-4] # separetely measured with for stability
])

experimental_rh_withh = np.array([
    [1.6045967741935485, -6.186624936278171],
    [1.6308064516129033, -6.47743753284885],
    [1.6579032258064517, -6.7267860882898045],
    [1.6858870967741935, -6.977007978565755],
])
experimental_rh_withh[:, 0] = 1000/experimental_rh_withh[:, 0]
experimental_rh_withh[:, 1] = np.exp(experimental_rh_withh[:, 1])

experimental_rh_noh = np.array([
    [1.6578378516934573, -7.624424103017261],
    [1.685850344357727, -7.873637375461223],
    [1.714743124650077, -8.130157372493203],
    [1.7446683710294304, -8.355890911789109],
])
experimental_rh_noh[:, 0] = 1000/experimental_rh_noh[:, 0]
experimental_rh_noh[:, 1] = np.exp(experimental_rh_noh[:, 1])

# %%
plt.rcParams.update(plt.rcParamsDefault)
if True: 
    fontsize = 12
    font = {'family': 'serif', 'size': fontsize}
    plt.rc('font', **font)
    plt.rc('text', usetex=True)
    plt.rc('text.latex', preamble=r'\usepackage{amsmath}')

#Rh
rh_nano_rate = np.array([6.13752E-06, 0.002483373, 0.155086166])
rh_nano_err = np.array([5.99636E-07, 0.000234715, 0.008899498])
rh_surf_rate = np.array([9.26E-04, 2.37E-01, 9.21E+00])
rh_surf_err = np.array([0, 0, 0])

# Pd 
pd_nano_rate = np.array([1.08951E-05, 0.002056465, 0.036609932])
pd_nano_err = np.array([7.24651E-07, 6.40838E-05, 0.001218916])
pd_surf_rate = np.array([1.79E-09, 2.51E-06, 1.18E-04])
pd_surf_err = np.array([0, 0, 0])

t_range = [400, 500, 600]
fig = plt.figure(figsize=[6, 4])
ax = fig.add_subplot(111)

linewidth = 2.5
markersize = 8

#Rh
#plt.errorbar([400, 500, 600], [6.13752E-06, 0.001567895, 0.061051135], yerr=[5.99636E-07, 0.000153183, 0.005964696], label='Kinetics', marker='o', color='tab:orange', linestyle='dashed')
ax.errorbar(t_range, rh_nano_rate, yerr=rh_nano_err, label='Nanoparticle', marker='s', color='tab:orange', linestyle='dashed', linewidth=linewidth, markersize=markersize, fillstyle='none')
ax.errorbar(t_range, rh_surf_rate, yerr=rh_surf_err, label='All (111)', marker='o', color='tab:orange', linestyle='-', linewidth=linewidth, markersize=markersize)
#Pd
#plt.errorbar([400, 500, 600], [1.08951E-05, 0.001881148, 0.036706527], yerr=[7.24651E-07, 0.00011661, 0.002007956], label='Kinetics', marker='o', color='tab:blue', linestyle='dashed')
ax.errorbar(t_range, pd_nano_rate, yerr=pd_nano_err, label='Nanoparticle', marker='s', color='tab:blue', linestyle='dashed', linewidth=linewidth, markersize=markersize, fillstyle='none')
ax.errorbar(t_range, pd_surf_rate, yerr=pd_surf_err, label='All (111)', marker='o', color='tab:blue', linestyle='-', linewidth=linewidth, markersize=markersize)

# Experimental Data
ax.plot(experimental_rh_data[:, 0], experimental_rh_data[:, 1], color='tab:orange', alpha=0.7, marker='^', linewidth=linewidth, markersize=markersize, linestyle='none', fillstyle='none', label='Stuff')
ax.plot(experimental_rh_withh[:, 0], experimental_rh_withh[:, 1], color='tab:orange', alpha=0.7, marker='^', linewidth=linewidth, markersize=markersize, linestyle='none', fillstyle='none')
# ax.plot(experimental_rh_noh[:, 0], experimental_rh_noh[:, 1], color='k', alpha=0.7, marker='^', linewidth=linewidth, markersize=markersize, linestyle='dashed', fillstyle='none')

ax.set_ylabel(r'Rate (mol$_{\text{prop}}$ mol$_{\text{dop}}^{-1}\text{s}^{-1}$)')
ax.set_xlabel('Temperature (K)')

#change x ticks
ax.set_xticks(t_range)

ax.set_yscale("log")
ax.set_ylim([1e-12, 8e1])

# Fix legend
if True:
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    linewidth-=1.5
    markersize-=1
    ax.legend(
        handles=[
            plt.errorbar([0], [0], [0], [0], label='Rh-Cu',  color='tab:orange', marker='s', fillstyle='none', linestyle='dashed', linewidth=linewidth, markersize=markersize-1), # , elinewidth=linewidth-0.5),
            plt.errorbar([0], [0], [0], [0], label='Rh all (111)',  color='tab:orange', marker='o', linewidth=linewidth, markersize=markersize-1), # , elinewidth=linewidth-0.5),
            Line2D([0], [0], label='Rh-Cu/SiO$_2$, Hannagan et al.',  color='tab:orange', marker='^', linestyle='none', fillstyle='none', linewidth=linewidth, markersize=markersize-1),
            plt.errorbar([0], [0], [0], [0], label='Pd-Cu', color='tab:blue', marker='s', fillstyle='none', linestyle='dashed', linewidth=linewidth, markersize=markersize-1), # , elinewidth=linewidth-0.5),
            plt.errorbar([0], [0], [0], [0], label='Pd all (111)',  color='tab:blue', marker='o', linewidth=linewidth, markersize=markersize-1), # , elinewidth=linewidth-0.5),            
            #Line2D([0], [0], linestyle='dashed', marker='s', label="Nanoparticle", color='k', linewidth=linewidth, markersize=markersize, fillstyle='none'),
            #patches.Patch(facecolor='tab:orange', label='Rhodium'),
            #Line2D([0], [0], linestyle='-', marker='o', color='k', label="All (111)", linewidth=linewidth, markersize=markersize),
        ],
        loc='lower right', ncols=2, columnspacing=-5 # Columnspacing negative to pull left and right columns together despite overlong bottom label 
        # bbox_to_anchor=(1.05, 1), borderaxespad=0.
    )
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
else:
    ax.legend(loc='lower right', ncols=2, columnspacing=-5)
fig.savefig("fig3_modelrates.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.show()
